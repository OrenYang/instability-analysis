# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import pandas as pd

# %%
x=torch.rand(5,3)
print(x)
# Out:
# tensor([[0.6888, 0.3553, 0.8682],
#         [0.5390, 0.4430, 0.2816],
#         [0.0726, 0.2706, 0.1827],
#         [0.5133, 0.3194, 0.4776],
#         [0.8433, 0.5195, 0.8985]])
